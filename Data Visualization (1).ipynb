# %% [markdown]
# Lab-1 Machine Learning for Robotics

# %% [markdown]
# Q1. Calculate the median, lower quartile, upper quartile, and interquartile range of the following data set of values: 20, 19, 21,
# 22, 23, 24, 25, 27, 26. Draw the box-plot for the above data and mention the five-point summary of data distribution.

# %%
import matplotlib.pyplot as plt
data=[20,19,21,22,23,24,25,27,26]
plt.boxplot(data)
plt.title("Boxplot of the given data")
plt.ylabel("Values")
plt.show()

# %% [markdown]
# Q2. Calories in Vanilla-Flavored Ice Cream Bars : 342 ,377 ,319, 353 , 295 ,234 ,294 ,286 ,377 ,182 ,310 ,439 ,111 ,201, 182 ,197 ,209 ,147
# ,190, 151 ,131 ,151. Analyze the dispersion of data (Mean, Median, Mode, Five Point summary, Outliers). List down the inferences.

# %%
import matplotlib.pyplot as plt
import numpy as np
import statistics as st
data=[342 ,377 ,319, 353 , 295 ,234 ,294 ,286 ,377 ,182 ,310 ,439 ,111 ,201, 182 ,197 ,209 ,147, 190, 151 ,131 ,151]
plt.boxplot(data)
plt.show()
print("Mean:", st.mean(data))
print("Median:", st.median(data))
print("Mode:", st.mode(data))
print("Quartiles:",st.quantiles(data))
print("Minimum:",min(data))
print("Maximum:",max(data))
print("Five point summary:",min(data),np.percentile(data,25),np.percentile(data,50), np.percentile(data,75),max(data))
Q1=np.percentile(data,25)
Q3=np.percentile(data,75)
IQR=Q3-Q1
lower_bound=Q1-1.5*IQR
upper_bound=Q3+1.5*IQR
outliers = [x for x in data if x < lower_bound or x > upper_bound]
print("Outliers:",outliers)
# Out:
# Mean: 249
# Median: 221.5
# Mode: 377
# Quartiles: [174.25, 221.5, 324.75]
# Minimum: 111
# Maximum: 439
# Five point summary: 111 182.0 221.5 316.75 439
# Outliers: []

# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv("C:\\1432\\Lab1_Vanilla.csv")
plt.boxplot(df)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv("C:\\1432\\Lab1_Vanilla.csv")
plt.boxplot(df,vert=False)
plt.show()

# %% [markdown]
# Q3. Outliers

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
Data =pd.read_csv('C:\\1432\\Lab1_Tips.csv')
Data.boxplot(column =['total_bill'])
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
Data =pd.read_csv('C:\\1432\\Lab1_Tips.csv')
plt.boxplot(Data['total_bill'])
plt.show()

# %% [markdown]
# Q4. Outlier and Grid

# %%
import pandas as pd
import matplotlib.pyplot as plt
Data =pd.read_csv('C:\\1432\\Lab1_Tips.csv')
Data.boxplot(by ='day', column =['total_bill'], grid=False)
plt.ylabel('Total Bill')
plt.xlabel('Days')
plt.show()

# %% [markdown]
# Q5. With seaborn

# %%
pip install seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      -------------------------------------- 294.9/294.9 KB 4.5 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 25.3 is available.
# You should consider upgrading via the 'c:\Program Files\Python310\python.exe -m pip install --upgrade pip' command.

# %%
import seaborn
seaborn.set(style='whitegrid')
tip = seaborn.load_dataset('tips')
seaborn.boxplot(x='day', y='tip', data=tip)
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %% [markdown]
# Q6. Variability Example

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.read_csv("Lab1_StudentsPerformance.csv")
print("First 5 rows:")
print(df.head())
numeric_cols = ["math score", "reading score", "writing score"]
df_numeric = df[numeric_cols]
print("\nSummary Statistics:")
print(df_numeric.describe())

plt.figure(figsize=(12, 5))
for i, col in enumerate(numeric_cols):
    plt.subplot(1, 3, i+1)
    sns.boxplot(y=df[col])
    plt.title(f"Variability in {col}")
    plt.tight_layout()
    plt.show()
# Out:
# First 5 rows:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
# Summary Statistics:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# ...

# %% [markdown]
# Excercise 1: Apply variability to tips.csv

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.read_csv("Lab1_Tips.csv")
print("First 5 rows:")
print(df.head())
# Out:
# First 5 rows:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.shape
# Out:
# (244, 7)

# %%
numeric_cols=df.select_dtypes(include=np.number)
categorical_cols=df.select_dtypes(exclude=np.number)
print(numeric_cols.head())
print(categorical_cols.head())
# Out:
#    total_bill   tip  size
# 0       16.99  1.01     2
# 1       10.34  1.66     3
# 2       21.01  3.50     3
# 3       23.68  3.31     2
# 4       24.59  3.61     4
#       sex smoker  day    time
# 0  Female     No  Sun  Dinner
# 1    Male     No  Sun  Dinner
# 2    Male     No  Sun  Dinner
# 3    Male     No  Sun  Dinner
# 4  Female     No  Sun  Dinner

# %%
numeric_cols = ["total_bill", "tip", "size"]
df_numeric = df[numeric_cols]
print("\nSummary Statistics:")
print(df_numeric.describe())

plt.figure(figsize=(12, 5))
for i, col in enumerate(numeric_cols):
    plt.subplot(1, 3, i+1)
    sns.boxplot(y=df[col])
    plt.title(f"Variability in {col}")
    plt.tight_layout()
    plt.show()
# Out:
# Summary Statistics:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000
